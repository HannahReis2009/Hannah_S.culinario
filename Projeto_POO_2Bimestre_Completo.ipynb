# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:** Hannah Reis
#
# **Turma:** 2ATi
#
# **Tema Escolhido:**  Sistema de Receitas culinárias

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# ----------------------------------------------------------
# PARTE 1 – CLASSE PRINCIPAL, CONSTRUTOR, OBJETOS E EXIBIÇÃO
# ----------------------------------------------------------
import mysql.connector  # Hannah Reis

class ReceitaHannahReis:  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo):  # Hannah Reis
        self.nome = nome  # Hannah Reis
        self.ingredientes = ingredientes  # Hannah Reis
        self.__tempo_preparo = tempo_preparo  # Atributo privado – Parte 3 – Hannah Reis

    def exibir_dados_hannah_reis(self):  # Hannah Reis
        print(f"\nReceita: {self.nome}")  # Hannah Reis
        print("Ingredientes:")  # Hannah Reis
        for ingrediente in self.ingredientes:  # Hannah Reis
            print(f" - {ingrediente}")  # Hannah Reis
        print(f"Tempo de preparo: {self.__tempo_preparo} minutos")  # Hannah Reis
        print(f"Classificação: {self.classificar_preparo_hannah_reis()}")  # Parte 3 – Hannah Reis

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# ----------------------------------------------------------
# PARTE 2 – MÉTODOS DE AÇÃO E SUBCLASSE COM HERANÇA
# ----------------------------------------------------------

    def adicionar_ingrediente_hannah_reis(self, ingrediente):  # Hannah Reis
        self.ingredientes.append(ingrediente)  # Hannah Reis

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# ----------------------------------------------------------
# PARTE 3 – ENCAPSULAMENTO (GET/SET) E LÓGICA INTERNA
# ----------------------------------------------------------

    def get_tempo_preparo_hannah_reis(self):  # Hannah Reis
        return self.__tempo_preparo  # Hannah Reis

    def set_tempo_preparo_hannah_reis(self, novo_tempo):  # Hannah Reis
        if novo_tempo > 0:  # Hannah Reis
            self.__tempo_preparo = novo_tempo  # Hannah Reis
        else:  # Hannah Reis
            print("Tempo inválido.")  # Hannah Reis

    def classificar_preparo_hannah_reis(self):  # Método com lógica interna – Hannah Reis
        if self.__tempo_preparo <= 20: return "Rápido"  # Hannah Reis
        elif self.__tempo_preparo <= 60: return "Médio"  # Hannah Reis
        else: return "Demorado"  # Hannah Reis

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# ----------------------------------------------------------
# PARTE 4 – POLIMORFISMO COM SUBCLASSE
# ----------------------------------------------------------

class ReceitaSobremesaHannahReis(ReceitaHannahReis):  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo, tipo_doce):  # Hannah Reis
        super().__init__(nome, ingredientes, tempo_preparo)  # Hannah Reis
        self.tipo_doce = tipo_doce  # Atributo exclusivo da subclasse – Hannah Reis

    def exibir_dados_hannah_reis(self):  # Polimorfismo (sobrescrevendo o método) – Hannah Reis
        super().exibir_dados_hannah_reis()  # Hannah Reis
        print(f"Tipo de doce: {self.tipo_doce}")  # Hannah Reis

# ----------------------------------------------------------
# PARTE 4 – CONEXÃO COM MYSQL (XAMPP + PHPMyAdmin)
# ----------------------------------------------------------

def conectar_banco_hannah_reis():  # Hannah Reis
    return mysql.connector.connect(
        host="localhost",  # Hannah Reis
        user="root",  # Hannah Reis
        password="",  # Hannah Reis
        database="receitas_hannah_reis"  # Hannah Reis
    )

def inserir_receita_hannah_reis(receita):  # Hannah Reis
    conn = conectar_banco_hannah_reis()  # Hannah Reis
    cursor = conn.cursor()  # Hannah Reis
    sql = "INSERT INTO receitas (nome, ingredientes, tempo_preparo) VALUES (%s, %s, %s)"  # Hannah Reis
    ingredientes_str = ", ".join(receita.ingredientes)  # Hannah Reis
    dados = (receita.nome, ingredientes_str, receita.get_tempo_preparo_hannah_reis())  # Hannah Reis
    cursor.execute(sql, dados)  # Hannah Reis
    conn.commit()  # Hannah Reis
    cursor.close()  # Hannah Reis
    conn.close()  # Hannah Reis
    print("Receita inserida com sucesso!")  # Hannah Reis

def listar_receitas_hannah_reis():  # Hannah Reis
    conn = conectar_banco_hannah_reis()  # Hannah Reis
    cursor = conn.cursor()  # Hannah Reis
    cursor.execute("SELECT * FROM receitas")  # Hannah Reis
    for (id, nome, ingredientes, tempo) in cursor.fetchall():  # Hannah Reis
        print(f"\nID: {id}\nNome: {nome}\nIngredientes: {ingredientes}\nTempo: {tempo} minutos")  # Hannah Reis
    cursor.close()  # Hannah Reis
    conn.close()  # Hannah Reis

def deletar_receita_hannah_reis(id_receita):  # Hannah Reis
    conn = conectar_banco_hannah_reis()  # Hannah Reis
    cursor = conn.cursor()  # Hannah Reis
    cursor.execute("DELETE FROM receitas WHERE id = %s", (id_receita,))  # Hannah Reis
    conn.commit()  # Hannah Reis
    cursor.close()  # Hannah Reis
    conn.close()  # Hannah Reis
    print("Receita deletada com sucesso!")  # Hannah Reis

# ----------------------------------------------------------
# PARTE 4 – INTERAÇÃO DINÂMICA COM O USUÁRIO
# ----------------------------------------------------------

def menu_hannah_reis():  # Hannah Reis
    while True:  # Hannah Reis
        print("\n==== Menu - Sistema de Receitas Hannah Reis ====")  # Hannah Reis
        print("1 - Adicionar nova receita")  # Hannah Reis
        print("2 - Listar receitas")  # Hannah Reis
        print("3 - Deletar receita")  # Hannah Reis
        print("0 - Sair")  # Hannah Reis
        opcao = input("Escolha uma opção: ")  # Hannah Reis

        if opcao == "1":  # Hannah Reis
            nome = input("Nome da receita: ")  # Hannah Reis
            ingredientes = input("Ingredientes (separados por vírgula): ").split(",")  # Hannah Reis
            tempo = int(input("Tempo de preparo (em minutos): "))  # Hannah Reis
            receita = ReceitaHannahReis(nome, [i.strip() for i in ingredientes], tempo)  # Hannah Reis
            inserir_receita_hannah_reis(receita)  # Hannah Reis
        elif opcao == "2":  # Hannah Reis
            listar_receitas_hannah_reis()  # Hannah Reis
        elif opcao == "3":  # Hannah Reis
            id_receita = int(input("Digite o ID da receita para deletar: "))  # Hannah Reis
            deletar_receita_hannah_reis(id_receita)  # Hannah Reis
        elif opcao == "0":  # Hannah Reis
            print("Saindo...")  # Hannah Reis
            break  # Hannah Reis
        else:  # Hannah Reis
            print("Opção inválida, tente novamente.")  # Hannah Reis

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# ==========================================================  # Hannah Reis
# SISTEMA DE RECEITAS - PROJETO POO COM BANCO DE DADOS       # Hannah Reis
# Desenvolvido por: Hannah Reis                              # Hannah Reis
# ==========================================================  # Hannah Reis

# -----------------------------                              # Hannah Reis
# IMPORTAÇÃO DE BIBLIOTECAS                                  # Hannah Reis
# -----------------------------                              # Hannah Reis
# Biblioteca para conectar ao MySQL – Hannah Reis  # Hannah Reis

# -----------------------------                              # Hannah Reis
# PARTE 1 – CLASSE PRINCIPAL                                 # Hannah Reis
# - Atributos                                                # Hannah Reis
# - Construtor                                               # Hannah Reis
# - Método de exibição                                       # Hannah Reis
# -----------------------------                              # Hannah Reis
class ReceitaHannahReis:  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo):  # Construtor – Hannah Reis  # Hannah Reis
        self.nome = nome  # Nome da receita – Hannah Reis  # Hannah Reis
        self.ingredientes = ingredientes  # Lista de ingredientes – Hannah Reis  # Hannah Reis
        self.__tempo_preparo = tempo_preparo  # Tempo privado – Hannah Reis (Parte 3)  # Hannah Reis

    def exibir_dados_hannah_reis(self):  # Método para exibir dados da receita – Hannah Reis  # Hannah Reis
        print(f"\nReceita: {self.nome}")  # Hannah Reis
        print("Ingredientes:")  # Hannah Reis
        for ingrediente in self.ingredientes:  # Hannah Reis
            print(f" - {ingrediente}")  # Hannah Reis
        print(f"Tempo de preparo: {self.__tempo_preparo} minutos")  # Hannah Reis
        print(f"Classificação: {self.classificar_preparo_hannah_reis()}")  # Chamada de método lógico – Hannah Reis  # Hannah Reis

# -----------------------------                              # Hannah Reis
# PARTE 2 – MÉTODOS DE AÇÃO                                  # Hannah Reis
# -----------------------------                              # Hannah Reis
    def adicionar_ingrediente_hannah_reis(self, ingrediente):  # Hannah Reis
        self.ingredientes.append(ingrediente)  # Hannah Reis

# -----------------------------                              # Hannah Reis
# PARTE 3 – ENCAPSULAMENTO                                   # Hannah Reis
# - get/set para tempo_preparo                               # Hannah Reis
# - Lógica interna: classificar preparo                      # Hannah Reis
# -----------------------------                              # Hannah Reis
    def get_tempo_preparo_hannah_reis(self):  # Hannah Reis
        return self.__tempo_preparo  # Hannah Reis

    def set_tempo_preparo_hannah_reis(self, novo_tempo):  # Hannah Reis
        if novo_tempo > 0:  # Hannah Reis
            self.__tempo_preparo = novo_tempo  # Hannah Reis
        else:  # Hannah Reis
            print("Tempo inválido.")  # Hannah Reis

    def classificar_preparo_hannah_reis(self):  # Método com lógica interna – Hannah Reis  # Hannah Reis
        if self.__tempo_preparo <= 20:  # Hannah Reis
            return "Rápido"  # Hannah Reis
        elif self.__tempo_preparo <= 60:  # Hannah Reis
            return "Médio"  # Hannah Reis
        else:  # Hannah Reis
            return "Demorado"  # Hannah Reis

# -----------------------------                              # Hannah Reis
# PARTE 2 – SUBCLASSE COM HERANÇA                            # Hannah Reis
# -----------------------------                              # Hannah Reis
class ReceitaSobremesaHannahReis(ReceitaHannahReis):  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo, tipo_doce):  # Hannah Reis
        super().__init__(nome, ingredientes, tempo_preparo)  # Hannah Reis
        self.tipo_doce = tipo_doce  # Novo atributo exclusivo – Hannah Reis  # Hannah Reis

    def exibir_dados_hannah_reis(self):  # Sobrescrita do método – Hannah Reis  # Hannah Reis
        super().exibir_dados_hannah_reis()  # Hannah Reis
        print(f"Tipo de doce: {self.tipo_doce}")  # Hannah Reis

# -----------------------------                              # Hannah Reis
# PARTE 4 – FUNÇÕES DE BANCO DE DADOS (MySQL)                # Hannah Reis
# -----------------------------                              # Hannah Reis

def conectar_banco_hannah_reis():  # Hannah Reis
    return mysql.connector.connect(  # Hannah Reis
        host="localhost",  # Hannah Reis
        user="root",  # Hannah Reis
        password="",  # Hannah Reis
        database="receitas_hannah_reis"  # Hannah Reis
    )  # Hannah Reis

def inserir_receita_hannah_reis(receita):  # Hannah Reis
    conn = conectar_banco_hannah_reis()  # Hannah Reis
    cursor = conn.cursor()  # Hannah Reis
    sql = "INSERT INTO receitas (nome, ingredientes, tempo_preparo) VALUES (%s, %s, %s)"  # Hannah Reis
    ingredientes_str = ", ".join(receita.ingredientes)  # Hannah Reis
    dados = (receita.nome, ingredientes_str, receita.get_tempo_preparo_hannah_reis())  # Hannah Reis
    cursor.execute(sql, dados)  # Hannah Reis
    conn.commit()  # Hannah Reis
    cursor.close()  # Hannah Reis
    conn.close()  # Hannah Reis
    print("✅ Receita inserida com sucesso!")  # Hannah Reis

def listar_receitas_hannah_reis():  # Hannah Reis
    conn = conectar_banco_hannah_reis()  # Hannah Reis
    cursor = conn.cursor()  # Hannah Reis
    cursor.execute("SELECT * FROM receitas")  # Hannah Reis
    receitas = cursor.fetchall()  # Hannah Reis
    if not receitas:  # Hannah Reis
        print("⚠️ Nenhuma receita cadastrada.")  # Hannah Reis
    for (id, nome, ingredientes, tempo) in receitas:  # Hannah Reis
        print(f"\n🔸 ID: {id}\n🔸 Nome: {nome}\n🔸 Ingredientes: {ingredientes}\n🔸 Tempo: {tempo} minutos")  # Hannah Reis
    cursor.close()  # Hannah Reis
    conn.close()  # Hannah Reis

def deletar_receita_hannah_reis(id_receita):  # Hannah Reis
    conn = conectar_banco_hannah_reis()  # Hannah Reis
    cursor = conn.cursor()  # Hannah Reis
    cursor.execute("DELETE FROM receitas WHERE id = %s", (id_receita,))  # Hannah Reis
    conn.commit()  # Hannah Reis
    cursor.close()  # Hannah Reis
    conn.close()  # Hannah Reis
    print("🗑️ Receita deletada com sucesso!")  # Hannah Reis

def buscar_por_ingrediente_hannah_reis(ingrediente):  # Hannah Reis
    conn = conectar_banco_hannah_reis()  # Hannah Reis
    cursor = conn.cursor()  # Hannah Reis
    sql = "SELECT * FROM receitas WHERE ingredientes LIKE %s"  # Hannah Reis
    busca = f"%{ingrediente}%"  # Hannah Reis
    cursor.execute(sql, (busca,))  # Hannah Reis
    resultados = cursor.fetchall()  # Hannah Reis

    if not resultados:  # Hannah Reis
        print("🔍 Nenhuma receita encontrada com esse ingrediente.")  # Hannah Reis
    else:  # Hannah Reis
        print(f"\n🔍 Resultados com '{ingrediente}':")  # Hannah Reis
        for (id, nome, ingredientes, tempo) in resultados:  # Hannah Reis
            print(f"\n🔸 ID: {id}\n🔸 Nome: {nome}\n🔸 Ingredientes: {ingredientes}\n🔸 Tempo: {tempo} minutos")  # Hannah Reis

    cursor.close()  # Hannah Reis
    conn.close()  # Hannah Reis

# -----------------------------                              # Hannah Reis
# PARTE 5 – MENU DE INTERAÇÃO                                # Hannah Reis
# -----------------------------                              # Hannah Reis
def menu_hannah_reis():  # Hannah Reis
    while True:  # Hannah Reis
        print("\n🍽️ SISTEMA DE RECEITAS - HANNAH REIS")  # Hannah Reis
        print("1 - Adicionar nova receita")  # Hannah Reis
        print("2 - Listar receitas")  # Hannah Reis
        print("3 - Deletar receita")  # Hannah Reis
        print("4 - Buscar receita por ingrediente")  # Hannah Reis
        print("0 - Sair")  # Hannah Reis
        opcao = input("Escolha uma opção: ")  # Hannah Reis

        if opcao == "1":  # Hannah Reis
            nome = input("Digite o nome da receita: ")  # Hannah Reis
            ingredientes = input("Informe os ingredientes (separados por vírgula): ").split(",")  # Hannah Reis
            try:  # Hannah Reis
                tempo = int(input("Informe o tempo de preparo (em minutos): "))  # Hannah Reis
                if tempo <= 0:  # Hannah Reis
                    print("⚠️ Tempo deve ser maior que zero.")  # Hannah Reis
                    continue  # Hannah Reis
            except ValueError:  # Hannah Reis
                print("⚠️ Por favor, insira um número válido.")  # Hannah Reis
                continue  # Hannah Reis
            receita = ReceitaHannahReis(nome, [i.strip() for i in ingredientes], tempo)  # Hannah Reis
            inserir_receita_hannah_reis(receita)  # Hannah Reis

        elif opcao == "2":  # Hannah Reis
            listar_receitas_hannah_reis()  # Hannah Reis

        elif opcao == "3":  # Hannah Reis
            try:  # Hannah Reis
                id_receita = int(input("Digite o ID da receita que deseja deletar: "))  # Hannah Reis
                deletar_receita_hannah_reis(id_receita)  # Hannah Reis
            except ValueError:  # Hannah Reis
                print("⚠️ ID inválido.")  # Hannah Reis

        elif opcao == "4":  # Hannah Reis
            termo = input("Digite o ingrediente para buscar: ").strip()  # Hannah Reis
            if termo:  # Hannah Reis
                buscar_por_ingrediente_hannah_reis(termo)  # Hannah Reis
            else:  # Hannah Reis
                print("⚠️ Digite um ingrediente válido.")  # Hannah Reis

        elif opcao == "0":  # Hannah Reis
            print("✅ Sistema encerrado. Até logo!")  # Hannah Reis
            break  # Hannah Reis
        else:  # Hannah Reis
            print("⚠️ Opção inválida, tente novamente.")  # Hannah Reis

# -----------------------------                              # Hannah Reis
# EXECUTAR SISTEMA                                           # Hannah Reis
# -----------------------------                              # Hannah Reis
menu_hannah_reis()  # Hannah Reis
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 9
#       1 # ==========================================================  # Hannah Reis
#       2 # SISTEMA DE RECEITAS - PROJETO POO COM BANCO DE DADOS       # Hannah Reis
#       3 # Desenvolvido por: Hannah Reis                              # Hannah Reis
#    (...)      7 # IMPORTAÇÃO DE BIBLIOTECAS                                  # Hannah Reis
#       8 # -----------------------------                              # Hannah Reis
# ----> 9 import mysql.connector  # Biblioteca para conectar ao MySQL – Hannah Reis  # Hannah Reis
#      11 # -----------------------------                              # Hannah Reis
#      12 # PARTE 1 – CLASSE PRINCIPAL                                 # Hannah Reis
#      13 # - Atributos                                                # Hannah Reis
# ...
