# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:** Hannah Reis
#
# **Turma:** 2ATi
#
# **Tema Escolhido:**  Sistema de Receitas culinárias

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Hannah Reis
class ReceitaHannahReis:  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo):  # Hannah Reis
        self.nome = nome  # Hannah Reis
        self.ingredientes = ingredientes  # Lista de strings  # Hannah Reis
        self.tempo_preparo = tempo_preparo  # Em minutos  # Hannah Reis

    def exibir_dados_hannah_reis(self):  # Hannah Reis
        print(f"Receita: {self.nome}")  # Hannah Reis
        print("Ingredientes:")  # Hannah Reis
        for ingrediente in self.ingredientes:  # Hannah Reis
            print(f" - {ingrediente}")  # Hannah Reis
        print(f"Tempo de preparo: {self.tempo_preparo} minutos")  # Hannah Reis
        print("-" * 40)  # Hannah Reis

# Criando objetos da classe ReceitaHannahReis  # Hannah Reis
receita1 = ReceitaHannahReis(  # Hannah Reis
    "Bolo de Cenoura",  # Hannah Reis
    ["cenoura", "ovos", "açúcar", "farinha", "óleo", "fermento"],  # Hannah Reis
    50  # Hannah Reis
)  # Hannah Reis

receita2 = ReceitaHannahReis(  # Hannah Reis
    "Panqueca de Frango",  # Hannah Reis
    ["frango desfiado", "massa de panqueca", "molho de tomate", "queijo"],  # Hannah Reis
    30  # Hannah Reis
)  # Hannah Reis

# Exibindo os dados das receitas  # Hannah Reis
receita1.exibir_dados_hannah_reis()  # Hannah Reis
receita2.exibir_dados_hannah_reis()  # Hannah Reis

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Hannah Reis
class ReceitaHannahReis:  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo):  # Hannah Reis
        self.nome = nome  # Hannah Reis
        self.ingredientes = ingredientes  # Hannah Reis
        self.tempo_preparo = tempo_preparo  # Hannah Reis

    def exibir_dados_hannah_reis(self):  # Hannah Reis
        print(f"Receita: {self.nome}")  # Hannah Reis
        print("Ingredientes:")  # Hannah Reis
        for ingrediente in self.ingredientes:  # Hannah Reis
            print(f" - {ingrediente}")  # Hannah Reis
        print(f"Tempo de preparo: {self.tempo_preparo} minutos")  # Hannah Reis
        print("-" * 40)  # Hannah Reis

    def adicionar_ingrediente_hannah_reis(self, ingrediente):  # Hannah Reis
        self.ingredientes.append(ingrediente)  # Hannah Reis
        print(f"Ingrediente '{ingrediente}' adicionado à receita '{self.nome}'.")  # Hannah Reis

    def alterar_tempo_preparo_hannah_reis(self, novo_tempo):  # Hannah Reis
        print(f"Tempo de preparo da receita '{self.nome}' alterado de {self.tempo_preparo} para {novo_tempo} minutos.")  # Hannah Reis
        self.tempo_preparo = novo_tempo  # Hannah Reis

# Subclasse herdando de ReceitaHannahReis  # Hannah Reis
class ReceitaSobremesaHannahReis(ReceitaHannahReis):  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo, tipo_doce):  # Hannah Reis
        super().__init__(nome, ingredientes, tempo_preparo)  # Hannah Reis
        self.tipo_doce = tipo_doce  # novo atributo exclusivo da subclasse  # Hannah Reis

    def exibir_dados_sobremesa_hannah_reis(self):  # Hannah Reis
        self.exibir_dados_hannah_reis()  # Hannah Reis
        print(f"Tipo de doce: {self.tipo_doce}")  # Hannah Reis
        print("=" * 40)  # Hannah Reis

# Criando objetos e testando  # Hannah Reis
bolo = ReceitaHannahReis("Bolo de Chocolate", ["chocolate", "farinha", "ovos", "açúcar"], 45)  # Hannah Reis
bolo.exibir_dados_hannah_reis()  # Hannah Reis
bolo.adicionar_ingrediente_hannah_reis("fermento")  # Hannah Reis
bolo.alterar_tempo_preparo_hannah_reis(50)  # Hannah Reis
bolo.exibir_dados_hannah_reis()  # Hannah Reis

# Criando uma receita da subclasse  # Hannah Reis
mousse = ReceitaSobremesaHannahReis(  # Hannah Reis
    "Mousse de Maracujá",  # Hannah Reis
    ["maracujá", "leite condensado", "creme de leite"],  # Hannah Reis
    20,  # Hannah Reis
    "gelado"  # Hannah Reis
)  # Hannah Reis
mousse.exibir_dados_sobremesa_hannah_reis()  # Hannah Reis

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Hannah Reis
class ReceitaHannahReis:  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo):  # Hannah Reis
        self.nome = nome  # Hannah Reis
        self.ingredientes = ingredientes  # Hannah Reis
        self.__tempo_preparo = tempo_preparo  # Hannah Reis (atributo privado)

    def exibir_dados_hannah_reis(self):  # Hannah Reis
        print(f"Receita: {self.nome}")  # Hannah Reis
        print("Ingredientes:")  # Hannah Reis
        for ingrediente in self.ingredientes:  # Hannah Reis
            print(f" - {ingrediente}")  # Hannah Reis
        print(f"Tempo de preparo: {self.__tempo_preparo} minutos")  # Hannah Reis
        print(f"Classificação: {self.classificar_preparo_hannah_reis()}")  # Hannah Reis
        print("-" * 40)  # Hannah Reis

    def adicionar_ingrediente_hannah_reis(self, ingrediente):  # Hannah Reis
        self.ingredientes.append(ingrediente)  # Hannah Reis
        print(f"Ingrediente '{ingrediente}' adicionado à receita '{self.nome}'.")  # Hannah Reis

    def get_tempo_preparo_hannah_reis(self):  # Hannah Reis
        return self.__tempo_preparo  # Hannah Reis

    def set_tempo_preparo_hannah_reis(self, novo_tempo):  # Hannah Reis
        if novo_tempo > 0:  # Hannah Reis
            print(f"Tempo de preparo da receita '{self.nome}' alterado de {self.__tempo_preparo} para {novo_tempo} minutos.")  # Hannah Reis
            self.__tempo_preparo = novo_tempo  # Hannah Reis
        else:  # Hannah Reis
            print("Tempo inválido. O valor deve ser maior que zero.")  # Hannah Reis

    def classificar_preparo_hannah_reis(self):  # Hannah Reis (lógica interna)
        if self.__tempo_preparo <= 20:  # Hannah Reis
            return "Rápido"  # Hannah Reis
        elif self.__tempo_preparo <= 60:  # Hannah Reis
            return "Médio"  # Hannah Reis
        else:  # Hannah Reis
            return "Demorado"  # Hannah Reis

# Subclasse herdando de ReceitaHannahReis  # Hannah Reis
class ReceitaSobremesaHannahReis(ReceitaHannahReis):  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo, tipo_doce):  # Hannah Reis
        super().__init__(nome, ingredientes, tempo_preparo)  # Hannah Reis
        self.tipo_doce = tipo_doce  # Hannah Reis

    def exibir_dados_sobremesa_hannah_reis(self):  # Hannah Reis
        self.exibir_dados_hannah_reis()  # Hannah Reis
        print(f"Tipo de doce: {self.tipo_doce}")  # Hannah Reis
        print("=" * 40)  # Hannah Reis

# Criando objetos e testando  # Hannah Reis
bolo = ReceitaHannahReis("Bolo de Laranja", ["laranja", "açúcar", "ovos", "farinha"], 70)  # Hannah Reis
bolo.exibir_dados_hannah_reis()  # Hannah Reis
bolo.set_tempo_preparo_hannah_reis(25)  # Hannah Reis
bolo.adicionar_ingrediente_hannah_reis("fermento")  # Hannah Reis
bolo.exibir_dados_hannah_reis()  # Hannah Reis

# Criando uma receita da subclasse  # Hannah Reis
pudim = ReceitaSobremesaHannahReis(  # Hannah Reis
    "Pudim de Leite",  # Hannah Reis
    ["leite condensado", "leite", "ovos", "açúcar"],  # Hannah Reis
    90,  # Hannah Reis
    "assado"  # Hannah Reis
)  # Hannah Reis
pudim.exibir_dados_sobremesa_hannah_reis()  # Hannah Reis

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import mysql.connector  # Hannah Reis

# Hannah Reis
class ReceitaHannahReis:  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo):  # Hannah Reis
        self.nome = nome  # Hannah Reis
        self.ingredientes = ingredientes  # Hannah Reis
        self.__tempo_preparo = tempo_preparo  # Hannah Reis

    def adicionar_ingrediente_hannah_reis(self, ingrediente):  # Hannah Reis
        self.ingredientes.append(ingrediente)  # Hannah Reis
        print(f"Ingrediente '{ingrediente}' adicionado à receita '{self.nome}'.")  # Hannah Reis

    def get_tempo_preparo_hannah_reis(self):  # Hannah Reis
        return self.__tempo_preparo  # Hannah Reis

    def set_tempo_preparo_hannah_reis(self, novo_tempo):  # Hannah Reis
        if novo_tempo > 0:  # Hannah Reis
            print(f"Tempo de preparo da receita '{self.nome}' alterado de {self.__tempo_preparo} para {novo_tempo} minutos.")  # Hannah Reis
            self.__tempo_preparo = novo_tempo  # Hannah Reis
        else:  # Hannah Reis
            print("Tempo inválido. O valor deve ser maior que zero.")  # Hannah Reis

    def classificar_preparo_hannah_reis(self):  # Hannah Reis (lógica interna)
        if self.__tempo_preparo <= 20:  # Hannah Reis
            return "Rápido"  # Hannah Reis
        elif self.__tempo_preparo <= 60:  # Hannah Reis
            return "Médio"  # Hannah Reis
        else:  # Hannah Reis
            return "Demorado"  # Hannah Reis

    def exibir_dados_hannah_reis(self):  # Hannah Reis
        print(f"Receita: {self.nome}")  # Hannah Reis
        print("Ingredientes:")  # Hannah Reis
        for ingrediente in self.ingredientes:  # Hannah Reis
            print(f"- {ingrediente}")  # Hannah Reis
        print(f"Tempo de preparo: {self.__tempo_preparo} minutos")  # Hannah Reis
        print(f"Classificação: {self.classificar_preparo_hannah_reis()}")  # Hannah Reis
        print("-" * 40)  # Hannah Reis

# Subclasse herdando de ReceitaHannahReis  # Hannah Reis
class ReceitaSobremesaHannahReis(ReceitaHannahReis):  # Hannah Reis
    def __init__(self, nome, ingredientes, tempo_preparo, tipo_doce):  # Hannah Reis
        super().__init__(nome, ingredientes, tempo_preparo)  # Hannah Reis
        self.tipo_doce = tipo_doce  # Hannah Reis

    def exibir_dados_hannah_reis(self):  # Hannah Reis (polimorfismo)
        super().exibir_dados_hannah_reis()  # Hannah Reis (chama o método da classe base)
        print(f"Tipo de doce: {self.tipo_doce}")  # Hannah Reis
        print("=" * 40)  # Hannah Reis

# Hannah Reis
class BancoDeDadosHannahReis:  # Hannah Reis
    def __init__(self, host, user, password, nome_banco):  # Hannah Reis
        self.conexao = mysql.connector.connect(  # Hannah Reis (conecta ao banco de dados MySQL)
            host=host,  # Hannah Reis (endereço do servidor MySQL)
            user=user,  # Hannah Reis (usuário MySQL)
            password=password,  # Hannah Reis (senha do MySQL)
            database=nome_banco  # Hannah Reis (nome do banco de dados)
        )  # Hannah Reis
        self.cursor = self.conexao.cursor()  # Hannah Reis
        self.criar_tabela_hannah_reis()  # Hannah Reis

    def criar_tabela_hannah_reis(self):  # Hannah Reis
        self.cursor.execute('''  # Hannah Reis
            CREATE TABLE IF NOT EXISTS receitas (  # Hannah Reis
                id INT AUTO_INCREMENT PRIMARY KEY,  # Hannah Reis (ajustado para MySQL)
                nome VARCHAR(255),  # Hannah Reis
                ingredientes TEXT,  # Hannah Reis
                tempo_preparo INT,  # Hannah Reis
                tipo_doce VARCHAR(100)  # Hannah Reis (nova coluna para sobremesas)
            )  # Hannah Reis
        ''')  # Hannah Reis
        self.conexao.commit()  # Hannah Reis

    def inserir_receita_hannah_reis(self, receita):  # Hannah Reis
        ingredientes_str = ", ".join(receita.ingredientes)  # Hannah Reis
        tipo_doce = getattr(receita, 'tipo_doce', None)  # Hannah Reis (verifica se o atributo 'tipo_doce' existe)
        self.cursor.execute("INSERT INTO receitas (nome, ingredientes, tempo_preparo, tipo_doce) VALUES (%s, %s, %s, %s)",  # Hannah Reis
                            (receita.nome, ingredientes_str, receita.get_tempo_preparo_hannah_reis(), tipo_doce))  # Hannah Reis
        self.conexao.commit()  # Hannah Reis
        print("Receita inserida com sucesso! ✅")  # Hannah Reis

    def listar_receitas_hannah_reis(self):  # Hannah Reis
        self.cursor.execute("SELECT * FROM receitas")  # Hannah Reis
        resultados = self.cursor.fetchall()  # Hannah Reis
        for linha in resultados:  # Hannah Reis
            print(f"ID: {linha[0]} | Nome: {linha[1]} | Ingredientes: {linha[2]} | Tempo: {linha[3]} minutos | Tipo de Doce: {linha[4]}")  # Hannah Reis

    def deletar_receita_hannah_reis(self, nome):  # Hannah Reis
        self.cursor.execute("DELETE FROM receitas WHERE nome = %s", (nome,))  # Hannah Reis
        self.conexao.commit()  # Hannah Reis
        print(f"Receita '{nome}' excluída com sucesso.")  # Hannah Reis

    def fechar_conexao_hannah_reis(self):  # Hannah Reis
        self.conexao.close()  # Hannah Reis

# Teste com banco de dados  # Hannah Reis
bd = BancoDeDadosHannahReis(host="localhost", user="seu_usuario", password="sua_senha", nome_banco="receitas_hannah_reis")  # Hannah Reis

# Criando uma receita e inserindo no banco  # Hannah Reis
bolo = ReceitaHannahReis("Bolo de Laranja", ["laranja", "açúcar", "ovos", "farinha"], 70)  # Hannah Reis
bolo.exibir_dados_hannah_reis()  # Hannah Reis
bd.inserir_receita_hannah_reis(bolo)  # Hannah Reis

# Criando uma receita da subclasse e inserindo no banco  # Hannah Reis
pudim = ReceitaSobremesaHannahReis(  # Hannah Reis
    "Pudim de Leite",  # Hannah Reis
    ["leite condensado", "leite", "ovos", "açúcar"],  # Hannah Reis
    90,  # Hannah Reis
    "assado"  # Hannah Reis
)  # Hannah Reis
pudim.exibir_dados_hannah_reis()  # Hannah Reis
bd.inserir_receita_hannah_reis(pudim)  # Hannah Reis

# Listando receitas no banco de dados  # Hannah Reis
bd.listar_receitas_hannah_reis()  # Hannah Reis

# Excluindo receita  # Hannah Reis
bd.deletar_receita_hannah_reis("Bolo de Laranja")  # Hannah Reis

# Fechando conexão  # Hannah Reis
bd.fechar_conexao_hannah_reis()  # Hannah Reis

# Teste com banco de dados  # Hannah Reis
bd = BancoDeDadosHannahReis(host="localhost", user="seu_usuario", password="sua_senha", nome_banco="receitas_hannah_reis")  # Hannah Reis

# Criando uma receita e inserindo no banco  # Hannah Reis
minha_receita = ReceitaHannahReis("Escondidinho", ["batata", "carne moída", "queijo"], 60)  # Hannah Reis
bd.inserir_receita_hannah_reis(minha_receita)  # Hannah Reis

# Listando receitas  # Hannah Reis
bd.listar_receitas_hannah_reis()  # Hannah Reis

# Excluindo receita  # Hannah Reis
bd.deletar_receita_hannah_reis("Escondidinho")  # Hannah Reis

# Fechando conexão  # Hannah Reis
bd.fechar_conexao_hannah_reis()  # Hannah Reis

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 5
